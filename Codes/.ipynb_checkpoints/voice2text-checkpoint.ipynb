# %%
# If you're using Google Colab and not running locally, run this cell.

## Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg portaudio19-dev
# !pip install unidecode
# !pip install pyaudio

# ## Install NeMo
BRANCH = 'r1.4.0'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[asr]

## Install TorchAudio
# !pip install torchaudio==0.9.0

## Grab the config we'll use in this example
# !mkdir configs
# Out:
# Requirement already satisfied: wget in d:\anaconda3\lib\site-packages (3.2)
# 'apt-get' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# Requirement already satisfied: unidecode in d:\anaconda3\lib\site-packages (1.3.7)
# Requirement already satisfied: pyaudio in d:\anaconda3\lib\site-packages (0.2.14)
# Collecting nemo_toolkit[asr]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision r1.4.0) to c:\users\miran\appdata\local\temp\pip-install-8yc9lv1j\nemo-toolkit_09a16f832eb14311a6acdb9afb0701e5
#   Resolved https://github.com/NVIDIA/NeMo.git to commit 7ab7cbd9781d4614c1794fb0f453d81cde4ac6ea
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.2 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.21.5)
# Requirement already satisfied: onnx>=1.7.0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.15.0)
# Requirement already satisfied: python-dateutil in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (2.8.2)
# Requirement already satisfied: torch<1.10,>1.7 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.9.0)
# Requirement already satisfied: wrapt in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.14.1)
# Requirement already satisfied: ruamel.yaml in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.18.5)
# Requirement already satisfied: scikit-learn in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.2.1)
# Requirement already satisfied: sentencepiece<1.0.0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.1.99)
# Requirement already satisfied: tqdm>=4.41.0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (4.64.1)
# Requirement already satisfied: numba in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.56.4)
# Requirement already satisfied: wget in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (3.2)
# Requirement already satisfied: frozendict in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (2.3.7)
# Requirement already satisfied: unidecode in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.3.7)
# Requirement already satisfied: braceexpand in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.1.7)
# Requirement already satisfied: editdistance in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.6.2)
# Requirement already satisfied: inflect in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (7.0.0)
# Requirement already satisfied: kaldi-io in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.9.8)
# Requirement already satisfied: librosa in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.10.1)
# Requirement already satisfied: marshmallow in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (3.20.1)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (23.0)
# Requirement already satisfied: soundfile in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.12.1)
# Requirement already satisfied: sox in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.4.1)
# Requirement already satisfied: kaldi-python-io in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.2.2)
# Requirement already satisfied: kaldiio in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (2.18.0)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.10.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.5.3)
# Requirement already satisfied: g2p_en in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (2.1.0)
# Requirement already satisfied: pydub in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.25.1)
# Requirement already satisfied: pyannote.core in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (5.0.0)
# Requirement already satisfied: pyannote.metrics in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (3.2.1)
# Requirement already satisfied: torch-stft in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.1.4)
# Requirement already satisfied: ipywidgets in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (8.0.4)
# Requirement already satisfied: matplotlib in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (3.7.3)
# Requirement already satisfied: pytorch-lightning<1.5,>=1.4.8 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.4.9)
# Requirement already satisfied: torchmetrics>=0.4.1rc0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: transformers>=4.0.1 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (4.24.0)
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (0.1.62)
# Requirement already satisfied: omegaconf>=2.1.0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1.0 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.3.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in d:\anaconda3\lib\site-packages (from hydra-core>=1.1.0->nemo_toolkit[asr]) (4.9.3)
# Requirement already satisfied: importlib-resources in d:\anaconda3\lib\site-packages (from hydra-core>=1.1.0->nemo_toolkit[asr]) (5.2.0)
# Requirement already satisfied: PyYAML>=5.1.0 in d:\anaconda3\lib\site-packages (from omegaconf>=2.1.0->nemo_toolkit[asr]) (6.0)
# Requirement already satisfied: protobuf>=3.20.2 in d:\anaconda3\lib\site-packages (from onnx>=1.7.0->nemo_toolkit[asr]) (3.20.3)
# Requirement already satisfied: future>=0.17.1 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.18.3)
# Requirement already satisfied: fsspec!=2021.06.0,>=2021.05.0 in d:\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2023.4.0)
# Requirement already satisfied: tensorboard>=2.2.0 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.9.0)
# Requirement already satisfied: pyDeprecate==0.3.1 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.3.1)
# Requirement already satisfied: typing-extensions in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.7.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in d:\anaconda3\lib\site-packages (from torchmetrics>=0.4.1rc0->nemo_toolkit[asr]) (0.10.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm>=4.41.0->nemo_toolkit[asr]) (0.4.6)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (0.17.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (2022.7.9)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (2.29.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (0.11.4)
# Requirement already satisfied: nltk>=3.2.4 in d:\anaconda3\lib\site-packages (from g2p_en->nemo_toolkit[asr]) (3.7)
# Requirement already satisfied: distance>=0.1.3 in d:\anaconda3\lib\site-packages (from g2p_en->nemo_toolkit[asr]) (0.1.3)
# Requirement already satisfied: pydantic>=1.9.1 in d:\anaconda3\lib\site-packages (from inflect->nemo_toolkit[asr]) (2.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (3.0.5)
# Requirement already satisfied: audioread>=2.1.9 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (0.3)
# Requirement already satisfied: msgpack>=1.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.0.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (0.39.1)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (66.0.0)
# Requirement already satisfied: importlib-metadata in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (6.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\lib\site-packages (from scikit-learn->nemo_toolkit[asr]) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in d:\anaconda3\lib\site-packages (from soundfile->nemo_toolkit[asr]) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (3.0.9)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil->nemo_toolkit[asr]) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->nemo_toolkit[asr]) (2022.7)
# Requirement already satisfied: sortedcontainers>=2.0.4 in d:\anaconda3\lib\site-packages (from pyannote.core->nemo_toolkit[asr]) (2.4.0)
# Requirement already satisfied: pyannote.database>=4.0.1 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (5.0.1)
# Requirement already satisfied: docopt>=0.6.2 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (0.8.10)
# Requirement already satisfied: sympy>=1.1 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (1.11.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in d:\anaconda3\lib\site-packages (from ruamel.yaml->nemo_toolkit[asr]) (0.2.8)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0->soundfile->nemo_toolkit[asr]) (2.21)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.8.4)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda3\lib\site-packages (from importlib-resources->hydra-core>=1.1.0->nemo_toolkit[asr]) (3.11.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.5.6)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (6.2)
# Requirement already satisfied: backcall in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.17.1)
# Requirement already satisfied: pickleshare in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (2.15.1)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk>=3.2.4->g2p_en->nemo_toolkit[asr]) (8.1.7)
# Requirement already satisfied: appdirs in d:\anaconda3\lib\site-packages (from pooch>=1.0->librosa->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: typer>=0.2.1 in d:\anaconda3\lib\site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->nemo_toolkit[asr]) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in d:\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->nemo_toolkit[asr]) (2.6.3)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda3\lib\site-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[asr]) (1.2.1)
# Requirement already satisfied: absl-py>=0.4 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.46.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.6.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.38.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2022.12.7)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (5.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (5.3.0)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.5)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in d:\anaconda3\lib\site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in d:\anaconda3\lib\site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (13.3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.1.1)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (2.5.2)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (305.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda3\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.1.2)
# DEPRECATION: git+https://github.com/NVIDIA/NeMo.git@r1.4.0#egg=nemo_toolkit[asr] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git 'C:\Users\miran\AppData\Local\Temp\pip-install-8yc9lv1j\nemo-toolkit_09a16f832eb14311a6acdb9afb0701e5'
#   Running command git checkout -b r1.4.0 --track origin/r1.4.0
#   branch 'r1.4.0' set up to track 'origin/r1.4.0'.
#   Switched to a new branch 'r1.4.0'
# Requirement already satisfied: torchaudio==0.9.0 in d:\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: torch==1.9.0 in d:\anaconda3\lib\site-packages (from torchaudio==0.9.0) (1.9.0)
# Requirement already satisfied: typing-extensions in d:\anaconda3\lib\site-packages (from torch==1.9.0->torchaudio==0.9.0) (4.7.1)
# 子目录或文件 configs 已经存在。

# %%
# !python asr-1.py record myvoice.wav 30
# Out:
# Recording ...
# Finished.

# %%
# !python asr-1.py play myvoice.wav 30

# %%
# !python asr-1.py transcribe myvoice.wav
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json: 100%|██████████| 159/159 [00:00<00:00, 77.2kB/s]
# D:\Anaconda3\lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\miran\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
#
# Downloading tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# Downloading tokenizer_config.json: 100%|██████████| 163/163 [00:00<00:00, 57.2kB/s]
#
# Downloading config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# Downloading config.json: 100%|██████████| 1.60k/1.60k [00:00<00:00, 849kB/s]
#
# Downloading vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading vocab.json: 100%|██████████| 291/291 [00:00<?, ?B/s]
#
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 85.0/85.0 [00:00<?, ?B/s]
#
# Downloading pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   3%|▎         | 10.5M/378M [00:00<00:10, 35.3MB/s]
# Downloading pytorch_model.bin:   6%|▌         | 21.0M/378M [00:00<00:08, 41.9MB/s]
# Downloading pytorch_model.bin:   8%|▊         | 31.5M/378M [00:00<00:08, 40.1MB/s]
# Downloading pytorch_model.bin:  11%|█         | 41.9M/378M [00:01<00:08, 39.6MB/s]
# Downloading pytorch_model.bin:  14%|█▍        | 52.4M/378M [00:01<00:08, 39.3MB/s]
# Downloading pytorch_model.bin:  17%|█▋        | 62.9M/378M [00:01<00:08, 38.9MB/s]
# Downloading pytorch_model.bin:  19%|█▉        | 73.4M/378M [00:01<00:07, 38.9MB/s]
# Downloading pytorch_model.bin:  22%|██▏       | 83.9M/378M [00:02<00:07, 38.6MB/s]
# Downloading pytorch_model.bin:  25%|██▍       | 94.4M/378M [00:02<00:07, 38.6MB/s]
# Downloading pytorch_model.bin:  28%|██▊       | 105M/378M [00:02<00:07, 38.5MB/s]
# Downloading pytorch_model.bin:  31%|███       | 115M/378M [00:02<00:06, 38.6MB/s]
# Downloading pytorch_model.bin:  33%|███▎      | 126M/378M [00:03<00:06, 38.6MB/s]
# Downloading pytorch_model.bin:  36%|███▌      | 136M/378M [00:03<00:06, 38.4MB/s]
# Downloading pytorch_model.bin:  39%|███▉      | 147M/378M [00:03<00:05, 38.5MB/s]
# Downloading pytorch_model.bin:  42%|████▏     | 157M/378M [00:04<00:05, 38.5MB/s]
# Downloading pytorch_model.bin:  44%|████▍     | 168M/378M [00:04<00:05, 38.4MB/s]
# Downloading pytorch_model.bin:  47%|████▋     | 178M/378M [00:04<00:05, 38.7MB/s]
# Downloading pytorch_model.bin:  50%|████▉     | 189M/378M [00:04<00:04, 38.5MB/s]
# Downloading pytorch_model.bin:  53%|█████▎    | 199M/378M [00:05<00:04, 38.4MB/s]
# Downloading pytorch_model.bin:  56%|█████▌    | 210M/378M [00:05<00:04, 38.4MB/s]
# Downloading pytorch_model.bin:  58%|█████▊    | 220M/378M [00:05<00:04, 38.5MB/s]
# Downloading pytorch_model.bin:  61%|██████    | 231M/378M [00:05<00:03, 38.4MB/s]
# Downloading pytorch_model.bin:  64%|██████▍   | 241M/378M [00:06<00:03, 38.3MB/s]
# Downloading pytorch_model.bin:  67%|██████▋   | 252M/378M [00:06<00:03, 38.5MB/s]
# Downloading pytorch_model.bin:  69%|██████▉   | 262M/378M [00:06<00:03, 38.5MB/s]
# Downloading pytorch_model.bin:  72%|███████▏  | 273M/378M [00:07<00:02, 38.5MB/s]
# Downloading pytorch_model.bin:  75%|███████▍  | 283M/378M [00:07<00:02, 38.4MB/s]
# Downloading pytorch_model.bin:  78%|███████▊  | 294M/378M [00:07<00:02, 38.5MB/s]
# Downloading pytorch_model.bin:  81%|████████  | 304M/378M [00:07<00:01, 38.3MB/s]
# Downloading pytorch_model.bin:  83%|████████▎ | 315M/378M [00:08<00:01, 38.4MB/s]
# Downloading pytorch_model.bin:  86%|████████▌ | 325M/378M [00:08<00:01, 38.4MB/s]
# Downloading pytorch_model.bin:  89%|████████▉ | 336M/378M [00:08<00:01, 38.5MB/s]
# Downloading pytorch_model.bin:  92%|█████████▏| 346M/378M [00:08<00:00, 38.4MB/s]
# Downloading pytorch_model.bin:  94%|█████████▍| 357M/378M [00:09<00:00, 38.3MB/s]
# Downloading pytorch_model.bin:  97%|█████████▋| 367M/378M [00:09<00:00, 38.4MB/s]
# Downloading pytorch_model.bin: 100%|█████████▉| 377M/378M [00:09<00:00, 38.5MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 378M/378M [00:09<00:00, 38.6MB/s]

# %%
# !python asr-1.py evaluate myvoice_transcription.txt ground-truth.txt
