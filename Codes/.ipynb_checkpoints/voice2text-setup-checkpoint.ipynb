# %% [markdown]
# ### Online Speech Recognition with the NVIDIA NeMo toolkit
#
# This portion of the lab is **not graded**. Here we demonstrate how you can build a speech engine that performs ASR on a stream of microphone audio in real time.
#
# This notebook is based on this jupyer notebook provided by the NeMo team at NVIDIA: https://github.com/NVIDIA/NeMo/blob/main/tutorials/asr/Online_ASR_Microphone_Demo.ipynb

# %%
"""
Please run notebook locally (if you have all the dependencies and a GPU). 
Technically you can run this notebook on Google Colab but you need to set up microphone for Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
5. Set up microphone for Colab
"""
# If you're using Google Colab and not running locally, run this cell.

## Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg portaudio19-dev
# !pip install unidecode
# !pip install pyaudio

# ## Install NeMo
BRANCH = 'r1.4.0'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[asr]

## Install TorchAudio
# !pip install torchaudio==0.9.0

## Grab the config we'll use in this example
# !mkdir configs
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=803b2a1d54c757b616ae00b6a043274c95044d6881a7af6e7291a3363fe2bd3f
#   Stored in directory: c:\users\miran\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# 'apt-get' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# Collecting unidecode
#   Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#      ---------------------------------------- 0.0/235.5 kB ? eta -:--:--
#      ------------------------------------- 235.5/235.5 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.7
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp38-cp38-win_amd64.whl (164 kB)
#      ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#      -------------------------------------- 164.1/164.1 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14
# Collecting nemo_toolkit[asr]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision r1.4.0) to c:\users\miran\appdata\local\temp\pip-install-jx06vo2i\nemo-toolkit_bbd0ff5da72145dbb35f82264b73e5b3
#   Resolved https://github.com/NVIDIA/NeMo.git to commit 7ab7cbd9781d4614c1794fb0f453d81cde4ac6ea
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.2 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.21.5)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.15.0-cp38-cp38-win_amd64.whl (14.3 MB)
#      ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#      - -------------------------------------- 0.5/14.3 MB 14.2 MB/s eta 0:00:01
#      --- ------------------------------------ 1.3/14.3 MB 13.7 MB/s eta 0:00:01
#      ------- -------------------------------- 2.5/14.3 MB 17.7 MB/s eta 0:00:01
#      ----------- ---------------------------- 4.0/14.3 MB 21.2 MB/s eta 0:00:01
#      --------------- ------------------------ 5.4/14.3 MB 24.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 8.0/14.3 MB 28.5 MB/s eta 0:00:01
#      -------------------------- ------------- 9.5/14.3 MB 28.9 MB/s eta 0:00:01
#      ----------------------------- --------- 10.7/14.3 MB 31.2 MB/s eta 0:00:01
#      ----------------------------------- --- 12.9/14.3 MB 36.4 MB/s eta 0:00:01
#      --------------------------------------  14.3/14.3 MB 36.4 MB/s eta 0:00:01
#      --------------------------------------- 14.3/14.3 MB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr])
d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.3.7)
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting editdistance
#   Downloading editdistance-0.6.2-cp38-cp38-win_amd64.whl (22 kB)
# Collecting inflect
#   Downloading inflect-7.0.0-py3-none-any.whl (34 kB)
# Collecting kaldi-io
#   Downloading kaldi_io-0.9.8-py3-none-any.whl (16 kB)
# Collecting librosa
#   Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#      ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#      ---------------------------------------- 253.7/253.7 kB ? eta 0:00:00
# Collecting marshmallow
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ---------------------------------------- 0.0/49.4 kB ? eta -:--:--
#      ---------------------------------------- 49.4/49.4 kB ? eta 0:00:00
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (23.0)
# Collecting soundfile
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---------------------------------------- 1.0/1.0 MB 32.2 MB/s eta 0:00:00
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kaldiio
#   Downloading kaldiio-2.18.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.10.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (1.5.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#      -------------------- ------------------- 1.6/3.1 MB 52.2 MB/s eta 0:00:01
#      ---------------------------------------- 3.1/3.1 MB 39.8 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pyannote.core
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.5 kB ? eta -:--:--
#      ---------------------------------------- 58.5/58.5 kB 3.0 MB/s eta 0:00:00
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ---------------------------------------- 0.0/51.4 kB ? eta -:--:--
#      ---------------------------------------- 51.4/51.4 kB ? eta 0:00:00
# Collecting torch-stft
#   Downloading torch_stft-0.1.4-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: ipywidgets in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (8.0.4)
# Requirement already satisfied: matplotlib in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (3.7.3)
# Collecting pytorch-lightning<1.5,>=1.4.8
#   Downloading pytorch_lightning-1.4.9-py3-none-any.whl (925 kB)
#      ---------------------------------------- 0.0/925.8 kB ? eta -:--:--
#      ------------------------------------  921.6/925.8 kB 19.4 MB/s eta 0:00:01
#      ------------------------------------- 925.8/925.8 kB 14.8 MB/s eta 0:00:00
# Collecting torchmetrics>=0.4.1rc0
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ---------------------------------------- 0.0/805.2 kB ? eta -:--:--
#      ------------------------------------- 805.2/805.2 kB 25.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.0.1 in d:\anaconda3\lib\site-packages (from nemo_toolkit[asr]) (4.24.0)
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Collecting omegaconf>=2.1.0
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 0.0/79.5 kB ? eta -:--:--
#      ---------------------------------------- 79.5/79.5 kB ? eta 0:00:00
# Collecting hydra-core>=1.1.0
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ---------------------------------------- 0.0/154.5 kB ? eta -:--:--
#      ---------------------------------------- 154.5/154.5 kB ? eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      ---------------------------------------- 117.0/117.0 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-resources in d:\anaconda3\lib\site-packages (from hydra-core>=1.1.0->nemo_toolkit[asr]) (5.2.0)
# Requirement already satisfied: PyYAML>=5.1.0 in d:\anaconda3\lib\site-packages (from omegaconf>=2.1.0->nemo_toolkit[asr]) (6.0)
# Collecting protobuf>=3.20.2
#   Downloading protobuf-4.25.1-cp38-cp38-win_amd64.whl (413 kB)
#      ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#      ------------------------------------- 413.4/413.4 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2023.4.0)
# Requirement already satisfied: typing-extensions in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.7.1)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: future>=0.17.1 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.18.3)
# Requirement already satisfied: tensorboard>=2.2.0 in d:\anaconda3\lib\site-packages (from pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.9.0)
# Collecting lightning-utilities>=0.8.0
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm>=4.41.0->nemo_toolkit[asr]) (0.4.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (0.11.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (0.17.2)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (3.9.0)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (2.29.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda3\lib\site-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (2022.7.9)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ---------------------------------------- 0.0/180.3 kB ? eta -:--:--
#      ---------------------------------------- 180.3/180.3 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk>=3.2.4 in d:\anaconda3\lib\site-packages (from g2p_en->nemo_toolkit[asr]) (3.7)
# Requirement already satisfied: pydantic>=1.9.1 in d:\anaconda3\lib\site-packages (from inflect->nemo_toolkit[asr]) (2.3.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (3.0.5)
# Requirement already satisfied: ipython>=6.1.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (8.12.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (6.19.2)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in d:\anaconda3\lib\site-packages (from ipywidgets->nemo_toolkit[asr]) (4.0.5)
# Requirement already satisfied: joblib>=0.14 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: msgpack>=1.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.0.3)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: decorator>=4.3.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in d:\anaconda3\lib\site-packages (from librosa->nemo_toolkit[asr]) (1.4.0)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.7-cp38-cp38-win_amd64.whl (184 kB)
#      ---------------------------------------- 0.0/185.0 kB ? eta -:--:--
#      ------------------------------------- 185.0/185.0 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (6.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (0.39.1)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from numba->nemo_toolkit[asr]) (66.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\lib\site-packages (from scikit-learn->nemo_toolkit[asr]) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in d:\anaconda3\lib\site-packages (from soundfile->nemo_toolkit[asr]) (1.15.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib->nemo_toolkit[asr]) (3.0.9)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil->nemo_toolkit[asr]) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->nemo_toolkit[asr]) (2023.3)
# Requirement already satisfied: sortedcontainers>=2.0.4 in d:\anaconda3\lib\site-packages (from pyannote.core->nemo_toolkit[asr]) (2.4.0)
# Requirement already satisfied: sympy>=1.1 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (1.11.1)
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-5.0.1-py3-none-any.whl (48 kB)
#      ---------------------------------------- 0.0/48.1 kB ? eta -:--:--
#      ---------------------------------------- 48.1/48.1 kB ? eta 0:00:00
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tabulate>=0.7.7 in d:\anaconda3\lib\site-packages (from pyannote.metrics->nemo_toolkit[asr]) (0.8.10)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.8-cp38-cp38-win_amd64.whl (118 kB)
#      ---------------------------------------- 0.0/118.5 kB ? eta -:--:--
#      ---------------------------------------- 118.5/118.5 kB ? eta 0:00:00
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0->soundfile->nemo_toolkit[asr]) (2.21)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.8.4)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda3\lib\site-packages (from importlib-resources->hydra-core>=1.1.0->nemo_toolkit[asr]) (3.11.0)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (8.1.0)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.1.2)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (6.2)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (25.0.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (0.1.6)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (3.0.36)
# Requirement already satisfied: pickleshare in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.7.5)
# Requirement already satisfied: backcall in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.17.1)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (2.15.1)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk>=3.2.4->g2p_en->nemo_toolkit[asr]) (8.1.7)
# Requirement already satisfied: appdirs in d:\anaconda3\lib\site-packages (from pooch>=1.0->librosa->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: typer[all]>=0.2.1 in d:\anaconda3\lib\site-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->nemo_toolkit[asr]) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in d:\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->nemo_toolkit[asr]) (2.6.3)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda3\lib\site-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[asr]) (1.2.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.6.6)
# Requirement already satisfied: grpcio>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.46.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in d:\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.38.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (3.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (5.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (5.3.0)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.5)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in d:\anaconda3\lib\site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (13.3.4)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (2.1.1)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.2.2)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->nemo_toolkit[asr]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (2.5.2)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (305.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<1.5,>=1.4.8->nemo_toolkit[asr]) (3.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda3\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.1.2)
# Building wheels for collected packages: antlr4-python3-runtime, kaldi-python-io, nemo_toolkit, distance, docopt
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=de2aed5dbdeda2e7617607342cf5d2e483c186275d14ed37ca22c586cbafa4ad
#   Stored in directory: c:\users\miran\appdata\local\pip\cache\wheels\b1\a3\c2\6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for kaldi-python-io (setup.py): started
#   Building wheel for kaldi-python-io (setup.py): finished with status 'done'
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8965 sha256=484d597d4e8da3cab0e529c6c0f6ae0393c68071da2d8e8b8210ff3035ec4063
#   Stored in directory: c:\users\miran\appdata\local\pip\cache\wheels\8c\da\46\4afb7e26376c33af41c3ec388d5b63d34d186f6df1545cac30
#   Building wheel for nemo_toolkit (setup.py): started
#   Building wheel for nemo_toolkit (setup.py): finished with status 'done'
#   Created wheel for nemo_toolkit: filename=nemo_toolkit-1.4.0-py3-none-any.whl size=2535872 sha256=8a8f0ec10633fc763eeee1f14a6ec963107098b87ec7771506febced1553149f
#   Stored in directory: C:\Users\miran\AppData\Local\Temp\pip-ephem-wheel-cache-l6wofna5\wheels\9f\03\20\56744f94bb55242da0f80caa59c2521969ebb26a61e41b5121
#   Building wheel for distance (setup.py): started
#   Building wheel for distance (setup.py): finished with status 'done'
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16282 sha256=76301ad62ee616afa8a19f1728240295ac0adedaa4256cdd60d304774dbeb3b5
#   Stored in directory: c:\users\miran\appdata\local\pip\cache\wheels\fb\a8\64\6edcab63ec51512a87cacf9b3563c711ad6b7b05d61b704493
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13775 sha256=bf48664baf096829accb65e88aee3917ff8517fdf956f2a415fea0c68409652d
#   Stored in directory: c:\users\miran\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built antlr4-python3-runtime kaldi-python-io nemo_toolkit distance docopt
# Installing collected packages: sentencepiece, pydub, docopt, distance, braceexpand, antlr4-python3-runtime, webdataset, torch, soxr, sox, shellingham, ruamel.yaml.clib, pyDeprecate, protobuf, omegaconf, marshmallow, lightning-utilities, lazy-loader, kaldiio, kaldi-python-io, kaldi-io, editdistance, audioread, torchmetrics, soundfile, ruamel.yaml, pyannote.core, onnx, hydra-core, nemo_toolkit, librosa, inflect, torch-stft, pyannote.database, g2p_en, pytorch-lightning, pyannote.metrics
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0
#     Uninstalling torch-2.1.0:
#       Successfully uninstalled torch-2.1.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# Successfully installed antlr4-python3-runtime-4.9.3 audioread-3.0.1 braceexpand-0.1.7 distance-0.1.3 docopt-0.6.2 editdistance-0.6.2 g2p_en-2.1.0 hydra-core-1.3.2 inflect-7.0.0 kaldi-io-0.9.8 kaldi-python-io-1.2.2 kaldiio-2.18.0 lazy-loader-0.3 librosa-0.10.1 lightning-utilities-0.10.0 marshmallow-3.20.1 nemo_toolkit-1.4.0 omegaconf-2.3.0 onnx-1.15.0 protobuf-4.25.1 pyDeprecate-0.3.1 pyannote.core-5.0.0 pyannote.database-5.0.1 pyannote.metrics-3.2.1 pydub-0.25.1 pytorch-lightning-1.4.9 ruamel.yaml-0.18.5 ruamel.yaml.clib-0.2.8 sentencepiece-0.1.99 shellingham-1.5.4 soundfile-0.12.1 sox-1.4.1 soxr-0.3.7 torch-1.12.1 torch-stft-0.1.4 torchmetrics-1.2.0 webdataset-0.1.62
# DEPRECATION: git+https://github.com/NVIDIA/NeMo.git@r1.4.0#egg=nemo_toolkit[asr] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git 'C:\Users\miran\AppData\Local\Temp\pip-install-jx06vo2i\nemo-toolkit_bbd0ff5da72145dbb35f82264b73e5b3'
#   Running command git checkout -b r1.4.0 --track origin/r1.4.0
#   branch 'r1.4.0' set up to track 'origin/r1.4.0'.
#   Switched to a new branch 'r1.4.0'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.16.0 requires torch==2.1.0, but you have torch 1.9.1 which is incompatible.
# streamlit 1.21.0 requires protobuf<4,>=3.12, but you have protobuf 4.25.1 which is incompatible.

# %% [markdown]
# This notebook demonstrates automatic speech recognition (ASR) from a microphone's stream in NeMo.
#
# It is **not a recommended** way to do inference in production workflows. If you are interested in
# production-level inference using NeMo ASR models, please refer to NVIDIA RIVA: https://developer.nvidia.com/riva

# %% [markdown]
# The notebook requires PyAudio library to get a signal from an audio device.
# For Ubuntu, please run the following commands to install it:
# ```
# sudo apt-get install -y portaudio19-dev
# pip install pyaudio
# ```

# %% [markdown]
# This notebook requires the `torchaudio` library to be installed for MatchboxNet. Please follow the instructions available at the [torchaudio Github page](https://github.com/pytorch/audio#installation) to install the appropriate version of torchaudio.
#
# If you would like to install the latest version, please run the following command to install it:
#
# ```
# conda install -c pytorch torchaudio
# ```

# %%
import numpy as np
import pyaudio as pa
import os, time

# %%
import nemo
import nemo.collections.asr as nemo_asr

# %%
# sample rate, Hz
SAMPLE_RATE = 16000

# %% [markdown]
# ## Restore the model from NGC

# %%
asr_model = nemo_asr.models.EncDecCTCModel.from_pretrained('QuartzNet15x5Base-En')

# %% [markdown]
# ## Observing the config of the model

# %%
from omegaconf import OmegaConf
import copy

# %%
# Preserve a copy of the full config
cfg = copy.deepcopy(asr_model._cfg)
print(OmegaConf.to_yaml(cfg))

# %% [markdown]
# ### Modify preprocessor parameters for inference

# %%
# Make config overwrite-able
OmegaConf.set_struct(cfg.preprocessor, False)

# some changes for streaming scenario
cfg.preprocessor.dither = 0.0
cfg.preprocessor.pad_to = 0

# spectrogram normalization constants
normalization = {}
normalization['fixed_mean'] = [
     -14.95827016, -12.71798736, -11.76067913, -10.83311182,
     -10.6746914,  -10.15163465, -10.05378331, -9.53918999,
     -9.41858904,  -9.23382904,  -9.46470918,  -9.56037,
     -9.57434245,  -9.47498732,  -9.7635205,   -10.08113074,
     -10.05454561, -9.81112681,  -9.68673603,  -9.83652977,
     -9.90046248,  -9.85404766,  -9.92560366,  -9.95440354,
     -10.17162966, -9.90102482,  -9.47471025,  -9.54416855,
     -10.07109475, -9.98249912,  -9.74359465,  -9.55632283,
     -9.23399915,  -9.36487649,  -9.81791084,  -9.56799225,
     -9.70630899,  -9.85148006,  -9.8594418,   -10.01378735,
     -9.98505315,  -9.62016094,  -10.342285,   -10.41070709,
     -10.10687659, -10.14536695, -10.30828702, -10.23542833,
     -10.88546868, -11.31723646, -11.46087382, -11.54877829,
     -11.62400934, -11.92190509, -12.14063815, -11.65130117,
     -11.58308531, -12.22214663, -12.42927197, -12.58039805,
     -13.10098969, -13.14345864, -13.31835645, -14.47345634]
normalization['fixed_std'] = [
     3.81402054, 4.12647781, 4.05007065, 3.87790987,
     3.74721178, 3.68377423, 3.69344,    3.54001005,
     3.59530412, 3.63752368, 3.62826417, 3.56488469,
     3.53740577, 3.68313898, 3.67138151, 3.55707266,
     3.54919572, 3.55721289, 3.56723346, 3.46029304,
     3.44119672, 3.49030548, 3.39328435, 3.28244406,
     3.28001423, 3.26744937, 3.46692348, 3.35378948,
     2.96330901, 2.97663111, 3.04575148, 2.89717604,
     2.95659301, 2.90181116, 2.7111687,  2.93041291,
     2.86647897, 2.73473181, 2.71495654, 2.75543763,
     2.79174615, 2.96076456, 2.57376336, 2.68789782,
     2.90930817, 2.90412004, 2.76187531, 2.89905006,
     2.65896173, 2.81032176, 2.87769857, 2.84665271,
     2.80863137, 2.80707634, 2.83752184, 3.01914511,
     2.92046439, 2.78461139, 2.90034605, 2.94599508,
     2.99099718, 3.0167554,  3.04649716, 2.94116777]

cfg.preprocessor.normalize = normalization

# Disable config overwriting
OmegaConf.set_struct(cfg.preprocessor, True)

# %% [markdown]
# ## Setup preprocessor with these settings

# %%
asr_model.preprocessor = asr_model.from_config_dict(cfg.preprocessor)

# %%
# Set model to inference mode
asr_model.eval();

# %%
asr_model = asr_model.to(asr_model.device)

# %% [markdown]
# ## Setting up data for Streaming Inference

# %%
from nemo.core.classes import IterableDataset
from nemo.core.neural_types import NeuralType, AudioSignal, LengthsType
import torch
from torch.utils.data import DataLoader

# %%
# simple data layer to pass audio signal
class AudioDataLayer(IterableDataset):
    @property
    def output_types(self):
        return {
            'audio_signal': NeuralType(('B', 'T'), AudioSignal(freq=self._sample_rate)),
            'a_sig_length': NeuralType(tuple('B'), LengthsType()),
        }

    def __init__(self, sample_rate):
        super().__init__()
        self._sample_rate = sample_rate
        self.output = True
        
    def __iter__(self):
        return self
    
    def __next__(self):
        if not self.output:
            raise StopIteration
        self.output = False
        return torch.as_tensor(self.signal, dtype=torch.float32), \
               torch.as_tensor(self.signal_shape, dtype=torch.int64)
        
    def set_signal(self, signal):
        self.signal = signal.astype(np.float32)/32768.
        self.signal_shape = self.signal.size
        self.output = True

    def __len__(self):
        return 1

# %%
data_layer = AudioDataLayer(sample_rate=cfg.preprocessor.sample_rate)
data_loader = DataLoader(data_layer, batch_size=1, collate_fn=data_layer.collate_fn)

# %%
# inference method for audio signal (single instance)
def infer_signal(model, signal):
    data_layer.set_signal(signal)
    batch = next(iter(data_loader))
    audio_signal, audio_signal_len = batch
    audio_signal, audio_signal_len = audio_signal.to(asr_model.device), audio_signal_len.to(asr_model.device)
    log_probs, encoded_len, predictions = model.forward(
        input_signal=audio_signal, input_signal_length=audio_signal_len
    )
    return log_probs

# %%
# class for streaming frame-based ASR
# 1) use reset() method to reset FrameASR's state
# 2) call transcribe(frame) to do ASR on
#    contiguous signal's frames
class FrameASR:
    
    def __init__(self, model_definition,
                 frame_len=2, frame_overlap=2.5, 
                 offset=10):
        '''
        Args:
          frame_len: frame's duration, seconds
          frame_overlap: duration of overlaps before and after current frame, seconds
          offset: number of symbols to drop for smooth streaming
        '''
        self.vocab = list(model_definition['labels'])
        self.vocab.append('_')
        
        self.sr = model_definition['sample_rate']
        self.frame_len = frame_len
        self.n_frame_len = int(frame_len * self.sr)
        self.frame_overlap = frame_overlap
        self.n_frame_overlap = int(frame_overlap * self.sr)
        timestep_duration = model_definition['AudioToMelSpectrogramPreprocessor']['window_stride']
        for block in model_definition['JasperEncoder']['jasper']:
            timestep_duration *= block['stride'][0] ** block['repeat']
        self.n_timesteps_overlap = int(frame_overlap / timestep_duration) - 2
        self.buffer = np.zeros(shape=2*self.n_frame_overlap + self.n_frame_len,
                               dtype=np.float32)
        self.offset = offset
        self.reset()
        
    def _decode(self, frame, offset=0):
        assert len(frame)==self.n_frame_len
        self.buffer[:-self.n_frame_len] = self.buffer[self.n_frame_len:]
        self.buffer[-self.n_frame_len:] = frame
        logits = infer_signal(asr_model, self.buffer).cpu().numpy()[0]
        # print(logits.shape)
        decoded = self._greedy_decoder(
            logits[self.n_timesteps_overlap:-self.n_timesteps_overlap], 
            self.vocab
        )
        return decoded[:len(decoded)-offset]
    
    @torch.no_grad()
    def transcribe(self, frame=None, merge=True):
        if frame is None:
            frame = np.zeros(shape=self.n_frame_len, dtype=np.float32)
        if len(frame) < self.n_frame_len:
            frame = np.pad(frame, [0, self.n_frame_len - len(frame)], 'constant')
        unmerged = self._decode(frame, self.offset)
        if not merge:
            return unmerged
        return self.greedy_merge(unmerged)
    
    def reset(self):
        '''
        Reset frame_history and decoder's state
        '''
        self.buffer=np.zeros(shape=self.buffer.shape, dtype=np.float32)
        self.prev_char = ''

    @staticmethod
    def _greedy_decoder(logits, vocab):
        s = ''
        for i in range(logits.shape[0]):
            s += vocab[np.argmax(logits[i])]
        return s

    def greedy_merge(self, s):
        s_merged = ''
        
        for i in range(len(s)):
            if s[i] != self.prev_char:
                self.prev_char = s[i]
                if self.prev_char != '_':
                    s_merged += self.prev_char
        return s_merged

# %% [markdown]
# # Streaming Inference
#
# Streaming inference depends on a few factors, such as the frame length and buffer size. Experiment with a few values to see their effects in the below cells.

# %%
# duration of signal frame, seconds
FRAME_LEN = 1.0
# number of audio channels (expect mono signal)
CHANNELS = 1

CHUNK_SIZE = int(FRAME_LEN*SAMPLE_RATE)
asr = FrameASR(model_definition = {
                   'sample_rate': SAMPLE_RATE,
                   'AudioToMelSpectrogramPreprocessor': cfg.preprocessor,
                   'JasperEncoder': cfg.encoder,
                   'labels': cfg.decoder.vocabulary
               },
               frame_len=FRAME_LEN, frame_overlap=2, 
               offset=4)

# %%
asr.reset()

p = pa.PyAudio()
print('Available audio input devices:')
input_devices = []
for i in range(p.get_device_count()):
    dev = p.get_device_info_by_index(i)
    if dev.get('maxInputChannels'):
        input_devices.append(i)
        print(i, dev.get('name'))

if len(input_devices):
    dev_idx = -2
    while dev_idx not in input_devices:
        print('Please type input device ID:')
        dev_idx = int(input())

    empty_counter = 0

    def callback(in_data, frame_count, time_info, status):
        global empty_counter
        signal = np.frombuffer(in_data, dtype=np.int16)
        text = asr.transcribe(signal)
        if len(text):
            print(text,end='')
            empty_counter = asr.offset
        elif empty_counter > 0:
            empty_counter -= 1
            if empty_counter == 0:
                print(' ',end='')
        return (in_data, pa.paContinue)

    stream = p.open(format=pa.paInt16,
                    channels=CHANNELS,
                    rate=SAMPLE_RATE,
                    input=True,
                    input_device_index=dev_idx,
                    stream_callback=callback,
                    frames_per_buffer=CHUNK_SIZE)

    print('Listening...')

    stream.start_stream()
    
    # Interrupt kernel and then speak for a few more words to exit the pyaudio loop !
    try:
        while stream.is_active():
            time.sleep(0.1)
    finally:        
        stream.stop_stream()
        stream.close()
        p.terminate()

        print()
        print("PyAudio stopped")
    
else:
    print('ERROR: No audio input device found.')
